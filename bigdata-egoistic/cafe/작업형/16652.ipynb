# %% [markdown]
# import numpy as np
# import pandas as pd
# import scipy as sp

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/mobile/train.csv')

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df[['price_range']].head()
# Out:
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %% [markdown]
# ### Q1

# %%
df.groupby(['price_range', 'n_cores']).size().sort_values().groupby(level=0).tail(1)
# Out:
# price_range  n_cores
# 0            2          69
# 3            5          70
# 2            4          73
# 1            1          76
# dtype: int64

# %%
df.groupby(['price_range'])['n_cores'].value_counts().sort_values().groupby(level=0).tail(1)
# Out:
# price_range  n_cores
# 0            2          69
# 3            5          70
# 2            4          73
# 1            1          76
# Name: n_cores, dtype: int64

# %% [markdown]
# ### Q2

# %%
df[df['price_range']==3].corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000 -0.019588    -0.047833 -0.134352  0.083515
# blue               -0.019588  1.000000     0.074535  0.061992  0.031587
# clock_speed        -0.047833  0.074535     1.000000 -0.042840  0.095757
# dual_sim           -0.134352  0.061992    -0.042840  1.000000 -0.075681
# fc                  0.083515  0.031587     0.095757 -0.075681  1.000000
# four_g              0.014355  0.044653    -0.144051 -0.014096 -0.053781
# int_memory         -0.041099 -0.003080    -0.008301 -0.036384 -0.039115
# m_dep               0.033896 -0.016718    -0.075859 -0.056753 -0.042970
# mobile_wt          -0.002937 -0.030398     0.036738 -0.050991  0.064398
# n_cores            -0.066908 -0.045381    -0.052820 -0.078633 -0.047587
# pc                  0.025482  0.024459     0.052912 -0.051248  0.635166
# px_height          -0.082547  0.043505     0.046343 -0.074033  0.044692
# ...

# %%
data = df[df['price_range']==3].corr().unstack()
data.index.names = ['cate_1','cate_2']
data.name = 'value'

# %%
pd.DataFrame(data).reset_index().sort_values(['value'], ascending=False)
# Out:
#             cate_1         cate_2  value
# 0    battery_power  battery_power    1.0
# 220             pc             pc    1.0
# 66        dual_sim       dual_sim    1.0
# 88              fc             fc    1.0
# 110         four_g         four_g    1.0
# ..             ...            ...    ...
# 436    price_range      talk_time    NaN
# 437    price_range        three_g    NaN
# 438    price_range   touch_screen    NaN
# 439    price_range           wifi    NaN
# 440    price_range    price_range    NaN
#
# [441 rows x 3 columns]

# %%
df1 = df[df['price_range']==3].corr().unstack().sort_values(ascending=False)

# %%
df2 = df1.loc[df1 != 1]

# %%
df2[1]
# Out:
# 0.635165983662283
